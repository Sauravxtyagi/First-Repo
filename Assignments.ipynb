# %% [markdown]
# # Basics Excel

# %% [markdown]
# 2. Write a formula to calculate the total sales of Car and Bicyle only only.

# %% [markdown]
# print("Hello, World!")

# %%
# testing comment
""" testing
multiline comments
"""
# Out:
# ' testing \nmultiline comments\n'
